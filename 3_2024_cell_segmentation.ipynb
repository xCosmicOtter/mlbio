# %% [markdown]
# # Context
#
# Recent studies have shown that breast cancer continues to be the leading cause of death among women over the world. If detected at an early stage, it can be cured in 9 out of 10 cases.
#
# Automated detection and segmentation of cells from images are the crucial and fundamental steps for the measurement of cellular morphology that is crucial for brest cancer diagnosis and prognosis.
#
#
# In this notebook, you will learn how to train a segmentation as UNet with **monai** - a framwork based Pytorch Stadard for healthcare imaging.

# %% [markdown]
# ## Monai
#
# MONAI is a pytorch based open source AI framework launched by NVIDIA and King’s College London.
# It is integrated with training and modelling workflows in a native PyTorch Standard. t several places.

# %% [markdown]
# Install monai

# %%
# !pip install monai
# Out:
# Collecting monai
#   Downloading monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.4.1+cu121)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Downloading monai-1.3.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.3.2

# %% [markdown]
# Check the installation by running the following cell

# %%
import monai
monai.config.print_config()
# Out:
# MONAI version: 1.3.2
# Numpy version: 1.26.4
# Pytorch version: 2.4.1+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 59a7211070538586369afd4a01eca0a7fe2e742e
# MONAI __file__: /usr/local/lib/python3.10/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.2.1
# scikit-image version: 0.24.0
# scipy version: 1.13.1
# Pillow version: 10.4.0
# Tensorboard version: 2.17.0
# gdown version: 5.2.0
# TorchVision version: 0.19.1+cu121
# tqdm version: 4.66.5
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 2.2.2
# einops version: 0.8.0
# transformers version: 4.44.2
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# #  Dataset
#
# To train a model, we need to prepare some ingredients:
#
# 1. Dataset
# 2. Model
# 3. Loss function
# 4. Optimizer

# %% [markdown]
# # I. Create Dataset
#
# There are two ways to create your dataset:
# - with pytorch Dataset
# - with monai.data.Dataset.
#
# In this exercise, we will create our dataset using torch.utils.data.Dataset.

# %% [markdown]
# ## 1. List all files in folder
#
# Download the dataset from https://zenodo.org/record/1175282#.YMn_Qy-FDox
#
# Notice that there are two kind of folder : original cell picture folder and mask folders. Using your file explorer or some code, display one image and the corresponding image

# %%
# !unzip /content/TNBC_NucleiSegmentation.zip
# Out:
# Archive:  /content/TNBC_NucleiSegmentation.zip
#    creating: TNBC_NucleiSegmentation/
#    creating: TNBC_NucleiSegmentation/GT_01/
#   inflating: TNBC_NucleiSegmentation/GT_01/01_1.png
#    creating: __MACOSX/
#    creating: __MACOSX/TNBC_NucleiSegmentation/
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_01/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_1.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_2.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_3.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_4.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_5.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_6.png
#   inflating: TNBC_NucleiSegmentation/GT_01/01_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_01/._01_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_01
#    creating: TNBC_NucleiSegmentation/GT_02/
#   inflating: TNBC_NucleiSegmentation/GT_02/02_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_02/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_02/._02_1.png
#   inflating: TNBC_NucleiSegmentation/GT_02/02_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_02/._02_2.png
#   inflating: TNBC_NucleiSegmentation/GT_02/02_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_02/._02_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_02
#    creating: TNBC_NucleiSegmentation/GT_03/
#   inflating: TNBC_NucleiSegmentation/GT_03/03_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_03/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_03/._03_1.png
#   inflating: TNBC_NucleiSegmentation/GT_03/03_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_03/._03_2.png
#   inflating: TNBC_NucleiSegmentation/GT_03/03_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_03/._03_3.png
#   inflating: TNBC_NucleiSegmentation/GT_03/03_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_03/._03_4.png
#   inflating: TNBC_NucleiSegmentation/GT_03/03_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_03/._03_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_03
#    creating: TNBC_NucleiSegmentation/GT_04/
#   inflating: TNBC_NucleiSegmentation/GT_04/04_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_04/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_1.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_2.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_3.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_4.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_5.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_6.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_7.png
#   inflating: TNBC_NucleiSegmentation/GT_04/04_8.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_04/._04_8.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_04
#    creating: TNBC_NucleiSegmentation/GT_05/
#   inflating: TNBC_NucleiSegmentation/GT_05/05_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_05/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_05/._05_1.png
#   inflating: TNBC_NucleiSegmentation/GT_05/05_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_05/._05_2.png
#   inflating: TNBC_NucleiSegmentation/GT_05/05_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_05/._05_3.png
#   inflating: TNBC_NucleiSegmentation/GT_05/05_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_05/._05_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_05
#    creating: TNBC_NucleiSegmentation/GT_06/
#   inflating: TNBC_NucleiSegmentation/GT_06/06_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_06/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_06/._06_1.png
#   inflating: TNBC_NucleiSegmentation/GT_06/06_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_06/._06_2.png
#   inflating: TNBC_NucleiSegmentation/GT_06/06_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_06/._06_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_06
#    creating: TNBC_NucleiSegmentation/GT_07/
#   inflating: TNBC_NucleiSegmentation/GT_07/07_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_07/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_07/._07_1.png
#   inflating: TNBC_NucleiSegmentation/GT_07/07_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_07/._07_2.png
#   inflating: TNBC_NucleiSegmentation/GT_07/07_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_07/._07_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_07
#    creating: TNBC_NucleiSegmentation/GT_08/
#   inflating: TNBC_NucleiSegmentation/GT_08/08_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_08/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_08/._08_1.png
#   inflating: TNBC_NucleiSegmentation/GT_08/08_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_08/._08_2.png
#   inflating: TNBC_NucleiSegmentation/GT_08/08_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_08/._08_3.png
#   inflating: TNBC_NucleiSegmentation/GT_08/08_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_08/._08_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_08
#    creating: TNBC_NucleiSegmentation/GT_09/
#   inflating: TNBC_NucleiSegmentation/GT_09/09_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_09/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_1.png
#   inflating: TNBC_NucleiSegmentation/GT_09/09_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_2.png
#   inflating: TNBC_NucleiSegmentation/GT_09/09_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_3.png
#   inflating: TNBC_NucleiSegmentation/GT_09/09_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_4.png
#   inflating: TNBC_NucleiSegmentation/GT_09/09_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_5.png
#   inflating: TNBC_NucleiSegmentation/GT_09/09_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_09/._09_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_09
#    creating: TNBC_NucleiSegmentation/GT_10/
#   inflating: TNBC_NucleiSegmentation/GT_10/10_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_10/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_10/._10_1.png
#   inflating: TNBC_NucleiSegmentation/GT_10/10_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_10/._10_2.png
#   inflating: TNBC_NucleiSegmentation/GT_10/10_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_10/._10_3.png
#   inflating: TNBC_NucleiSegmentation/GT_10/10_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_10/._10_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_10
#    creating: TNBC_NucleiSegmentation/GT_11/
#   inflating: TNBC_NucleiSegmentation/GT_11/11_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/GT_11/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_11/._11_1.png
#   inflating: TNBC_NucleiSegmentation/GT_11/11_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_11/._11_2.png
#   inflating: TNBC_NucleiSegmentation/GT_11/11_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/GT_11/._11_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._GT_11
#    creating: TNBC_NucleiSegmentation/Slide_01/
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_4.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_5.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_6.png
#   inflating: TNBC_NucleiSegmentation/Slide_01/01_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_01/._01_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_01
#    creating: TNBC_NucleiSegmentation/Slide_02/
#   inflating: TNBC_NucleiSegmentation/Slide_02/02_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_02/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_02/._02_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_02/02_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_02/._02_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_02/02_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_02/._02_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_02
#    creating: TNBC_NucleiSegmentation/Slide_03/
#   inflating: TNBC_NucleiSegmentation/Slide_03/03_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/._03_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_03/03_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/._03_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_03/03_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/._03_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_03/03_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/._03_4.png
#   inflating: TNBC_NucleiSegmentation/Slide_03/03_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_03/._03_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_03
#    creating: TNBC_NucleiSegmentation/Slide_04/
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_4.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_5.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_6.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_7.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_7.png
#   inflating: TNBC_NucleiSegmentation/Slide_04/04_8.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_04/._04_8.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_04
#    creating: TNBC_NucleiSegmentation/Slide_05/
#   inflating: TNBC_NucleiSegmentation/Slide_05/05_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_05/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_05/._05_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_05/05_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_05/._05_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_05/05_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_05/._05_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_05/05_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_05/._05_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_05
#    creating: TNBC_NucleiSegmentation/Slide_06/
#   inflating: TNBC_NucleiSegmentation/Slide_06/06_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_06/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_06/._06_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_06/06_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_06/._06_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_06/06_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_06/._06_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_06
#    creating: TNBC_NucleiSegmentation/Slide_07/
#   inflating: TNBC_NucleiSegmentation/Slide_07/07_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_07/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_07/._07_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_07/07_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_07/._07_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_07/07_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_07/._07_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_07
#    creating: TNBC_NucleiSegmentation/Slide_08/
#   inflating: TNBC_NucleiSegmentation/Slide_08/08_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_08/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_08/._08_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_08/08_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_08/._08_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_08/08_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_08/._08_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_08/08_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_08/._08_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_08
#    creating: TNBC_NucleiSegmentation/Slide_09/
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_4.png
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_5.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_5.png
#   inflating: TNBC_NucleiSegmentation/Slide_09/09_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_09/._09_6.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_09
#    creating: TNBC_NucleiSegmentation/Slide_10/
#   inflating: TNBC_NucleiSegmentation/Slide_10/10_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_10/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_10/._10_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_10/10_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_10/._10_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_10/10_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_10/._10_3.png
#   inflating: TNBC_NucleiSegmentation/Slide_10/10_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_10/._10_4.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_10
#    creating: TNBC_NucleiSegmentation/Slide_11/
#   inflating: TNBC_NucleiSegmentation/Slide_11/11_1.png
#    creating: __MACOSX/TNBC_NucleiSegmentation/Slide_11/
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_11/._11_1.png
#   inflating: TNBC_NucleiSegmentation/Slide_11/11_2.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_11/._11_2.png
#   inflating: TNBC_NucleiSegmentation/Slide_11/11_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/Slide_11/._11_3.png
#   inflating: __MACOSX/TNBC_NucleiSegmentation/._Slide_11
#   inflating: __MACOSX/._TNBC_NucleiSegmentation

# %%
import matplotlib.pyplot as plt
from PIL import Image

image_folder = '/content/TNBC_NucleiSegmentation/GT_01/01_1.png'
mask_folder = '/content/TNBC_NucleiSegmentation/Slide_01/01_1.png'

image = Image.open(image_folder)
mask = Image.open(mask_folder)

# %%
plt.imshow(image)

# %%
plt.imshow(mask)

# %% [markdown]
# ## 2. Define a transform
# When you load your data, you need to define some transformation. For example, we want to convert image to the format [num_channels, spatial_dim_1, spatial_dim_2] because monai/pytorch use this format. We'll also need to convert the images to PyTorch tensors with transforms.ToTensor()
#
# The following code lets you load image and the labels and define several steps to transform the data.

# %%
# !pip install monai
# Out:
# Requirement already satisfied: monai in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.4.1+cu121)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)

# %%
import torch

from monai.transforms import Compose, LoadImage, EnsureChannelFirst, ToTensor, NormalizeIntensity
from monai.transforms import ScaleIntensity

from monai.data import PILReader

image_trans = Compose(
    [
        LoadImage(image_only=True, reader = PILReader(converter=lambda image: image.convert("RGB"))),
        EnsureChannelFirst(),
        NormalizeIntensity(),
        ToTensor(),
    ])


label_trans = Compose(
    [
        LoadImage(image_only=True),
        EnsureChannelFirst(),
        ScaleIntensity(),
        ToTensor(),
    ])

# %% [markdown]
# ## 3. Create dataset
#
# The following class CellDataset allows us to create our dataset from "image_files" and "label_files" where:
# - "image_files" is a list of image names
# - "label_files" is the list of segmentation names respectively.
#
# "im_trans" and "label_trans" are respectively the transforms for the images and their labels.

# %%
import torch

class CellDataset(torch.utils.data.Dataset):
    def __init__(self, image_files, label_files, im_trans, label_trans):
        self.image_files = image_files
        self.label_files = label_files
        self.im_trans = im_trans
        self.label_trans = label_trans

    def __len__(self):
        return(len(self.image_files))

    def __getitem__(self, index):
        return self.im_trans(self.image_files[index]), self.label_trans(self.label_files[index])

# %% [markdown]
# By using this class, create your training dataset et your test dataset. Remember to check if your dataset is loaded correctly.

# %%
import os
X_train = []
y_train = []

X_test = []
y_test = []


for i in range(1,10):
  for file in os.listdir(f'/content/TNBC_NucleiSegmentation/GT_0{i}'):
      y_train.append(f'/content/TNBC_NucleiSegmentation/GT_0{i}/{file}')
      X_train.append(f'/content/TNBC_NucleiSegmentation/Slide_0{i}/{file}')
for i in range(10,12):
  for file in os.listdir(f'/content/TNBC_NucleiSegmentation/GT_{i}'):
      y_test.append(f'/content/TNBC_NucleiSegmentation/GT_{i}/{file}')
      X_test.append(f'/content/TNBC_NucleiSegmentation/Slide_{i}/{file}')

# %%
train_dataset = CellDataset(X_train, y_train, image_trans, label_trans) # to change
test_dataset = CellDataset(X_test, y_test, image_trans, label_trans)

# %% [markdown]
# ## 4. DataLoader
#
# With the your dataset loaded, you have to pass it to a DataLoader. The torch.utils.data.DataLoader takes a dataset and returns batches of images and the corresponding labels. You can set various parameters like the batch size and if the data is shuffled after each epoch.
#
#
# The following code let you create a data loader for the train dataset, do the same to create a test_loader on the test_dataset. Name it **test_load**

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=4, shuffle=False)

# %% [markdown]
# ## 5. Now, time to check your dataloader.
#
# Execute the code following to check if your dataloader works correctly

# %%
import monai
im, seg = monai.utils.misc.first(train_loader)
im.shape
# Out:
# torch.Size([4, 3, 512, 512])

# %% [markdown]
# # II. Build your segmentation model with monai
#
# Monai already has a UNet model architecture : https://docs.monai.io/en/stable/networks.html#unet
#
# By using the monai.networks.nets module, build a UNet model for segmentation task in 2D. You'll have to choose the following parameters for the model:
#
# 1. dimensions (number of spatial dimensions)
# 2. in_channels (number of input channel)
# 3. out_channels (number of output channel)
# 4. channels
# 5. strides

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from monai.networks.nets import UNet

model = UNet(
    spatial_dims=2,
    in_channels=3,
    out_channels=1,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
)

# %% [markdown]
# # III. Define your loss function and optimizer
#
# For a segmentation prob, we usually use DiceLoss.
# Using monai.losses.DiceLoss, define your loss function and store it in the variable named **loss_function**. The option sigmoid = True should be used.

# %%
from monai.losses import DiceLoss

loss_function = DiceLoss(sigmoid=True)

# %% [markdown]
# With torch.optim, define an optimizer for your model. Use the Adam optimiser

# %%
optimizer = torch.optim.Adam(model.parameters(), 1e-3)

# %% [markdown]
# # IV. Trainning the model
#
# This time, we have all ingredients to train a segmentation model: a model, an optimizer, train_loader and a loss function.
#
# Monai use a standard PyTorch program style for training a deep learning model.
#
#
# The general process with Monai/Pytorch just for one learning step  as follows:
#
# 1. Load input and label of each batch.
#
# 2. Zero accumulated gradients with optimizer.zero_grad()
#
# 3. Compute the output from the model
#
# 4. Calculate the loss
#
# 5. Perform backprop with loss.backward()
#
# 6. Update the optimizer with optimizer.step()
#
#
# Complete the following code so that it do the training

# %%
epoch_loss_values = list()
for epoch in range(10):

    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device)
        optimizer.zero_grad()
        predictions = model(inputs)
        print(predictions.shape)
        print(labels.shape)
        loss_value = loss_function(predictions, labels)

        loss_value.backward()
        optimizer.step()

        epoch_loss += loss_value.item()
        epoch_len = len(train_dataset) // train_loader.batch_size
        print(f"{step}/{epoch_len}, train_loss: {loss_value.item():.4f}")


    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
# Out:
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.8645
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.6367
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.6722
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.6200
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.7936
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.6589
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.7456
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.8444
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.7233
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.6937
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.6927
# epoch 1 average loss: 0.7223
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.5229
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.7603
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.6833
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.7284
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.7434
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.6213
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.6170
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.6288
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.6232
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.5929
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.7391
# epoch 2 average loss: 0.6600
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.6820
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.4888
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.6908
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.7019
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.5448
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.7040
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.7386
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.6924
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.4889
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.6886
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.5278
# epoch 3 average loss: 0.6317
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.6201
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.7124
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.5899
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.3824
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.5714
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.8095
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.6081
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.5687
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.5950
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.6144
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.7302
# epoch 4 average loss: 0.6184
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.5988
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.4535
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.7107
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.5962
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.6427
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.5249
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.5364
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.8475
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.5150
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.5618
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.6133
# epoch 5 average loss: 0.6001
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.6040
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.3197
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.8719
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.6120
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.6684
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.5983
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.5513
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.5986
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.3942
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.6443
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.5292
# epoch 6 average loss: 0.5811
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.6556
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.7546
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.5108
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.5977
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.6171
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.6625
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.5182
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.5065
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.4307
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.4470
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.4746
# epoch 7 average loss: 0.5614
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.4769
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.5232
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.7844
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.5058
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.5169
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.4357
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.4539
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.7437
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.5370
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.4730
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.5526
# epoch 8 average loss: 0.5457
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.5763
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.6805
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.5899
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.4693
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.5348
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.5509
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.6658
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.5826
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.4703
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.3615
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.2966
# epoch 9 average loss: 0.5253
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 1/10, train_loss: 0.5014
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 2/10, train_loss: 0.5121
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 3/10, train_loss: 0.4949
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 4/10, train_loss: 0.5426
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 5/10, train_loss: 0.5020
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 6/10, train_loss: 0.4969
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 7/10, train_loss: 0.6292
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 8/10, train_loss: 0.5899
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 9/10, train_loss: 0.4437
# torch.Size([4, 1, 512, 512])
# torch.Size([4, 1, 512, 512])
# 10/10, train_loss: 0.4688
# torch.Size([3, 1, 512, 512])
# torch.Size([3, 1, 512, 512])
# 11/10, train_loss: 0.4891
# epoch 10 average loss: 0.5155

# %% [markdown]
# Display the prediction of your model on several image

# %%
import matplotlib.pyplot as plt
model.eval()
with torch.no_grad():
    for i, val_data in enumerate(test_loader):
        image, label = val_data[0].to(device), val_data[1].to(device)
        outputs = model(image)
        plt.figure(figsize=(16,5))
        plt.subplot(1,3,1)
        plt.imshow(image[0][0].cpu())
        plt.title("image")
        plt.subplot(1,3,2)
        plt.imshow(label[0][0].cpu())
        plt.title("labels")
        plt.subplot(1,3,3)
        plt.imshow(outputs[0][0].cpu())
        plt.title("prediction")
        plt.suptitle(f"loss {loss_function(outputs, label)}")
        plt.show()

# %% [markdown]
# Train another architecture (either another Unet architecture or find another segmentation model in the available models of Monai). Compare the results with the first model
